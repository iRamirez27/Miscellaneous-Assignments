# %%
import time

b_key = False		#lower tower room key
s_key = False		#stair key
g_key = False		#higher tower room key
fire = False		#whether or not the house is on fire
flower_1970 = False		#flower
kettle = False		#it's a kettle
fork = False          #operation fork is a go

list_inventory = []

def spacer ():
    print ("\t")
    print ("+++++++++++++++++++++++")
    print ("\t")

def Shia_LaBouf ():    #finished
	import os
	clear = lambda: os.system('clear')
	clear()

	time.sleep(3)
	print("You're walking in the woods. No one is around and your phone is dead. Out of the corner of your eye, you spot him.")
	print("\t")
	time.sleep(2.5)
	print("Shia LaBouf")
	print("\t")
	time.sleep(3)
	print("He's following you. About 30 feet back. He gets down on all fours and breaks into a sprint. He's gaining on you.")
	print("\t")
	time.sleep(2.5)
	print("Shia LaBouf")
	print ("\t")
	time.sleep(3)
	print ("You're looking for your car but you're all turned around. He's almost upon you now. And you can see there's blood on his face.")
	print ("\t")
	time.sleep(2.5)
	print ("My God! There's blood everywhere!")
	print ("\t")
	time.sleep(2.5)
	print ("Running for your life")
	print ("\t")
	print ("(from Shia LaBouf)")
	print ("\t")
	time.sleep(2.5)
	print ("He's brandishing a knife")
	print ("\t")
	print ("(it's Shia LaBouf)")
	print ("\t")
	time.sleep(2.5)
	print ("Lurking in the shadows.")
	print ("\t")
	time.sleep(2.5)
	print ("Hollywood superstar Shia LaBouf.")
	print ("\t")
	time.sleep(5)
	print ("Living in the woods")
	print ("\t")
	print ("(Shia LaBouf)")
	print ("\t")
	time.sleep(2.5)
	print ("Killing for sport")
	print ("\t")
	print ("(Shia LaBouf)")
	print ("\t")
	time.sleep(2.5)
	print ("Eating all the bodies.")
	print ("\t")
	time.sleep(2.5)
	print ("Actual cannibal Shia LaBouf.")
	print ("\t")
	time.sleep(5)
	print ("Now it's dark and you seem to have lost him.")
	print ("\t")
	time.sleep(2.5)
	print ("But you're hopelessly lost yourself.")
	print ("\t")
	time.sleep(2.5)
	print ("Stranded with a murderer.")
	print ("\t")
	time.sleep(2.5)
	print ("You creep silently through the underbrush.")
	print ("\t")
	time.sleep(3)
	print ("Aha! In the distance,")
	print ("\t")
	time.sleep(2.5)
	print ("A small cottage with a light on.")
	print ("\t")
	time.sleep(2.5)
	print ("Hope! You move stealthily toward it,")
	print ("\t")
	time.sleep(2.5)
	print ("But your leg! Ah! It's caught in a bear trap!")
	print ("\t")
	time.sleep(3)
	print ("Gnawing off your leg")
	print ("\t")
	print ("(quiet, quiet)")
	print ("\t")
	time.sleep(2.5)
	print ("Limping to the cottage")
	print ("\t")
	print ("(quiet, quiet)")
	print ("\t")
	time.sleep(2.5)
	print ("Now you're on the doorstep.")
	print ("\t")
	time.sleep(2.5)
	print ("Sitting inside: Shia LaBouf.")
	print ("\t")
	time.sleep(3)
	print ("Sharpening an axe")
	print ("\t")
	print ("(Shia LaBouf")
	print ("\t")
	time.sleep(2.5)
	print ("But he doesn't hear you enter")
	print ("\t")
	print ("(Shia LaBouf)")
	print ("\t")
	time.sleep(2.5)
	print ("You're sneaking up behind him,")
	print ("\t")
	time.sleep(2.5)
	print ("Strangling superstar Shia LaBouf.")
	print ("\t")
	time.sleep(3)
	print ("Fighting for your life with Shia LaBouf.")
	print ("\t")
	time.sleep(2.5)
	print ("Wrestling a knife from Shia LaBouf.")
	print ("\t")
	time.sleep(2.5)
	print ("Stab him in his kidney.")
	print ("\t")
	time.sleep(2.5)
	print ("Safe at last from Shia LaBouf.")
	print ("\t")
	time.sleep(3)
	print ("You limp into the dark woods,")
	print ("\t")
	time.sleep(2.5)
	print ("Blood oozing from your stump leg.")
	print ("\t")
	time.sleep(2.5)
	print ("But you have won; you have beaten,")
	print ("\t")
	time.sleep(2.5)
	print ("Shia LaBouf.")
	print ("\t")
	time.sleep(5)
	clear()
	print ("Wait! He isn't dead!")
	print ("\t")
	print ("(Shia surprise!)")
	print ("\t")
	time.sleep(2.5)
	print ("There's a gun to your head, and death in his eyes.")
	print ("\t")
	time.sleep(2.5)
	print ("But you can do Jiu Jitsu.")
	print ("\t")
	time.sleep(2.5)
	print ("Bodyslam susperstar Shia LaBouf.")
	print ("\t")
	time.sleep(3)
	print ("Legendary fight with Shia LaBouf.")
	print ("\t")
	time.sleep(2.5)
	print ("Normal Tuesday night for Shia LaBouf.")
	print ("\t")
	time.sleep(2.5)
	print ("You try and swing an axe at Shia LaBouf,")
	print ("\t")
	print ("But blood is oozing fast from your stump leg.")
	print ("\t")
	time.sleep(3)
	print ("He's dodging every swipe, he parries to the left.")
	print ("\t")
	time.sleep(2.5)
	print ("You counter to the right, you catch him in the neck.")
	print ("\t")
	time.sleep(2.5)
	print ("You're chopping off his head now.")
	print ("\t")
	time.sleep(2.5)
	print ("You have just decapitated Shia LaBouf.")
	print ("\t")
	time.sleep(4)
	print ("His head topples to the floor, expressionless")
	print ("\t")
	time.sleep(2.5)
	print ("You fall to your knees and catch your breath.")
	print ("\t")
	time.sleep(2.5)
	print ("You're finally safe, from Shia LaBouf.")
	print ("\t")

def entrance ():		#finished		starting point
	global b_key
	global s_key
	global g_key
	global flower_1970
	global fire
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("You are in a dimly lit room that seems like an entrance room to a house. In the wall in front of you is a doorway with a door that is slightly ajar. In the wall to your left is another doorway with an open door. On the wall to your right is a large painting with another closed door.")
	print("\t")
	print ("+++++++++++++++++++++++")
	if (fire == bool(True)):
		time.sleep(6)
		print ("\t")
		print ("You realize as you look around, that even though you are at the entrance to the house, there is no way out.")
		print ("\t")
		time.sleep(7)
		import os
		clear = lambda: os.system('clear')
		clear()
		print ("+++++++++++++++++++++++")
		print ("\t")
		print ("There is nothing left of the house.")
		print ("\t")
		print ("+++++++++++++++++++++++")
		time.sleep(6)
		print ("\t")
		print ("There is also nothing left of you.")
		print ("\t")
		time.sleep(8)
		clear()
		print ("+++++++++++++++++++++++")
		print ("\t")
		print ("The only thing left in the area, is a single calendula flower, in the midst of the ashes.")
		print ("\t")
		print ("+++++++++++++++++++++++")
	else:
		print ("\t")
		print ("Type 'inventory' to access your items.")
		print ("Your options are: Forwards, Left, Painting.")
		f = str(input("What would you like to do? "))
		print ("\t")
		x = ("You chose: ") + f
		print ("+++++++++++++++++++++++")
		print ("\t")
		print (x)
		if (f == "Shia LaBouf"):
			print ("\t")
			Shia_LaBouf()
		elif (f == "inventory") or (f == "Inventory"):
			inventory()
			print ("\t")
			entrance()
		elif (f == "Forwards") or (f == "forwards"):
			print ("\t")
			dining_area()
		elif (f == "Left") or (f == "left"):
			print ("\t")
			kitchen()
		elif (f == "Painting") or (f == "painting"):
			print ("\t")
			entrance_painting()
		else:
			unavailable()
			entrance()

def entrance_painting ():		#finished		item example
	global b_key
	global flower_1970
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("You walk over to the painting on the wall. You notice that one of the corners of the painting is peeling away from the frame.")
	spacer()
	print ("Type 'inventory' to access your items.")
	print ("Your options are: Peel, Return.")
	f = str(input("What would you like to do? "))
	spacer()
	x = ("You chose: ") + f
	print (x)
	if (f == "Shia LaBouf"):
		print ("\t")
		Shia_LaBouf()
	elif (f == "inventory") or (f == "Inventory"):
		inventory()
		print ("\t")
		entrance_painting()
	elif (f == "Peel") or (f == "peel"):
		if (b_key == bool(False)):
			spacer()
			print ("You notice a bronze key in a small hole behind the painting.")
			print ("Your options: Yes, No.")
			o = str(input("Do you take the key? "))
			spacer()
			y = ("You chose: ") + o
			print (y)
			print ("\t")
			if (o == "Yes") or (o == "yes") or (o == "y"):
				b_key = bool(True)
				list_inventory.append("Bronze Key")
				print ("+++++++++++++++++++++++")
				print ("\t")
				print ("You take the bronze key from the hole in the painting.")
				time.sleep(2.5)
				print ("\t")
				entrance_painting()
			elif (o == "No") or (o == "no") or (o == "n"):
				print ("+++++++++++++++++++++++")
				print ("\t")
				entrance_painting()
			else:
				unavailable()
				entrance_painting()
		else:
			spacer()
			print ("There is nothing behind the painting.")
			print ("\t")
			entrance_painting()
	elif (f == "Return") or (f == "return"):
		print ("\t")
		entrance()
	else:
		unavailable()
		entrance_painting()

def kitchen ():		#finished (kettle added)
	global b_key
	global s_key
	global g_key
	global flower_1970
	global kettle
	global fire
	print ("+++++++++++++++++++++++")
	print ("\t")
	if (kettle == bool(True)):
		print ("You appear to be in an old kitchen. It looks like whoever owned this house left in a hurry. There is a opened door in front of you and the door to the entrance is to your right. ")
	else:
		print ("You appear to be in an old kitchen. It looks like whoever owned this house left in a hurry. There is an opened door in front of you and the door to the entrance is to your right. There is a deserted kettle on what looks to be a stove.")
	print ("\t")
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("Type 'inventory' to access your items.")
	if (kettle == bool(True)):
		print ("Your options are: Forwards, Right")
	else:
		print ("Your options are: Forwards, Right, Kettle.")
	f = str(input("What would you like to do? "))
	print ("\t")
	x = ("You chose: ") + f
	print ("+++++++++++++++++++++++")
	print ("\t")
	print (x)
	if (f == "Shia LaBouf"):
		print ("\t")
		Shia_LaBouf()
	elif (f == "inventory") or (f == "Inventory"):
		inventory()
		print ("\t")
		kitchen()
	elif (f == "Forwards") or (f == "forwards"):
		print ("\t")
		dining_area()
	elif (f == "Right") or (f == "right"):
		if (fire == bool(True)):
			if (flower_1970 == bool(True)):
				print ("\t")
				fire_exit()
			else:
				print ("\t")
				entrance()
		else:
			print ("\t")
			entrance()
	elif (f == "Kettle") or (f == "kettle"):
		print ("\t")
		deserted_kettle()
	else:
		unavailable()
		kitchen()

def dining_area ():		#finished (fork added)
	global b_key
	global s_key
	global flower_1970
	global fire
	print ("+++++++++++++++++++++++")
	print ("\t")
	if (fork == bool(True)):
		print ("You have now entered a large room. It seems as though it had been used as a combination of a dining room and a living room. There are two open doors behind you, to your right and left. There is a closed door in a slanted wall that leads to a tower in front of you and to the right. There is a fourth door, in the corner, on the wall to your left. ")
	else:
		print("You have now entered a large room. It seems as though it had been used as a combination of a dining room and a living room. There is a large dining table in the middle of the room with a single fork on it. There are two open doors behind you, to your right and left. There is a closed door in a slanted wall that leads to a tower in front of you and to the right. There is a fourth door, in the corner, on the wall to your left.")
	spacer()
	print ("Type 'inventory' to access your items.")
	if (fork == bool(True)):
		print ("Your options are: Back Left, Back Right, Left Corner, Tower Door")
	else:
		print ("Your options are: Back Left, Back Right, Left Corner, Tower Door, Fork.")
	f = str(input("What would you like to do? "))
	print ("\t")
	x = "You chose: " + f
	print ("+++++++++++++++++++++++")
	print ("\t")
	print (x)
	if (f == "Shia LaBouf"):
		print ("\t")
		Shia_LaBouf()
	elif (f == "inventory") or (f == "Inventory"):
		inventory()
		print ("\t")
		dining_area()
	elif (f == "Fork") or (f == "fork"):
		print ("\t")
		strange_fork()
	elif (f == "Back Left") or (f == "back left"):
		print ("\t")
		kitchen()
	elif (f == "Back Right") or (f == "back right"):
		if (fire == bool(True)):
			if (flower_1970 == bool(True)):
				print ("\t")
				fire_exit()
			else:
				print ("\t")
				entrance()
		else:
			print ("\t")
			entrance()
	elif (f == "Left Corner") or (f == "left corner"):
		print ("\t")
		seating_area()
	elif (f == "Tower Door") or (f == "tower door"):
		if  (b_key == bool(True)):
			print ("\t")
			bottom_tower()
		else:
			spacer()
			print ("The door is locked.")
			time.sleep(1.5)
			print ("\t")
			dining_area()
	else:
		unavailable()
		dining_area()

def seating_area ():	#finished (window finished)
	global b_key
	global s_key
	global g_key
	global flower_1970
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("A quaint little seating area with a boarded up window. The door to the dining room is behind you. There is a window in front of you and there is a closed door to your left.")
	spacer()
	print ("Type 'inventory' to access your items.")
	print ("Your options are: Left, Back, Window.")
	f = str(input("What would you like to do? "))
	print ("\t")
	x = "Your choice: " + f
	print ("+++++++++++++++++++++++")
	print ("\t")
	print (x)
	if (f == "Shia LaBouf"):
		print ("\t")
		Shia_LaBouf()
	elif (f == "inventory") or (f == "Inventory"):
		inventory()
		print ("\t")
		seating_area()
	elif (f == "Left") or (f == "left"):
		if (s_key == bool(True)):
			print ("\t")
			hallway()
		else:
			spacer()
			print ("The door is locked.")
			time.sleep(1.5)
			print ("\t")
			seating_area()
	elif (f == "Back") or (f == "back"):
		print ("\t")
		dining_area()
	elif (f == "Window") or (f == "window"):
		print ("\t")
		window()
	else:
		unavailable()
		seating_area()

def hallway ():		#finished
	global b_key
	global s_key
	global g_key
	global flower_1970
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("It's a hallway with a flight of stairs and a screen door that appears to lead to a backyard. The door looks to be boarded closed from the outside. The seating area is behind you.")
	spacer()
	print ("Type 'inventory' to access your inventory.")
	print ("Your options are: Upstairs, Back.")
	f = str(input("What would you like to do? "))
	spacer()
	x = "You chose: " + f
	print (x)
	if (f == "Shia LaBouf"):
		print ("\t")
		Shia_LaBouf()
	elif (f == "Inventory") or (f == "inventory"):
		inventory()
		print ("\t")
		hallway()
	elif (f == "Upstairs") or  (f == "upstairs"):
		spacer()
		print ("You went up to the second floor of the house.")
		print ("\t")
		time.sleep(3)
		up_hallway()
	elif (f == "Back") or (f == "back"):
		print ("\t")
		seating_area()
	else:
		unavailable()
		hallway()

def bottom_tower ():     #finished
	global b_key
	global s_key
	global flower_1970
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("You used the bronze key to unlock the door to the tower.")
	print ("\t")
	print ("+++++++++++++++++++++++")
	time.sleep(1.5)
	print ("\t")
	print ("You entered the tower. You see sunlight just barely shining through the boarded-up windows. There are papers and maps scattered everywhere about the small room. There is a big piece of paper on the wall in front of you with pictures nailed to it. The pictures are of a mysterious forest and a drinking well.There also seems to be a picture of what looks like a blown-up city.")
	spacer()
	print ("Type 'inventory' to access your inventory.")
	print ("Your choices are: Paper, Return.")
	f = str(input("What would you like to do? "))
	print ("\t")
	x = "You chose: " + f
	print ("+++++++++++++++++++++++")
	print ("\t")
	print (x)
	if (f == "Shia LaBouf"):
		Shia_LaBouf ()
	elif (f == "inventory") or (f == "inventory"):
		inventory()
		print ("\t")
		bottom_tower()
	elif (f == "Paper") or (f == "paper") or (f == "p"):
		print ("\t")
		paper()
	elif (f == "Return") or (f == "return"):
		print ("\t")
		dining_area()
	else:
		unavailable()
		bottom_tower()

def fire_exit ():		#finished
	global fire
	global flower_1970
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("You are in a dimly lit room that seems like an entrance to a house. In the wall in front of you is a doorway with a door that is slightly ajar. In the wall to your left is another doorway with an open door. On the wall to your right is a large painting with another closed door. Along with the painting on the wall, there is a screen door that leads outside the house.")
	spacer()
	print ("Type 'inventory' to access your inventory.")
	print ("Your options are: Forwards, Left, Painting, Escape.")
	f = str(input("What would you like to do? "))
	spacer()
	x = "You chose: " + f
	print (x)
	if (f == "Shia LaBouf"):
		print ("\t")
		Shia_LaBouf()
	elif (f == "Inventory") or (f == "inventory"):
		inventory()
		print ("\t")
		fire_exit()
	elif (f == "Forwards") or (f == "forwards"):
		print ("\t")
		dining_area()
	elif (f == "Left") or (f == "left"):
		print ("\t")
		kitchen()
	elif (f == "Painting") or (f == "painting"):
		print ("\t")
		entrance_painting()
	elif (f == "Escape") or (f == "escape"):
		spacer()
		print ("You left the burning house.")
		print ("\t")
		print ("+++++++++++++++++++++++")
		time.sleep(7)
		import os
		clear = lambda: os.system('clear')
		clear()
		print ("+++++++++++++++++++++++")
		print ("\t")
		print ("You look back to see what happened to the house.")
		print ("\t")
		print ("+++++++++++++++++++++++")
		time.sleep(7)
		print ("\t")
		print ("The entire house has been reduced to ashes.")
		print ("\t")
		time.sleep(7)
		clear()
		print ("+++++++++++++++++++++++")
		print ("\t")
		print ("The only thing remaining is a single, untouched, calendula flower.")
		print ("\t")
		print ("+++++++++++++++++++++++")
	else:
		unavailable()
		fire_exit()

def strange_fork ():		#finished
	global fork
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("The fork is old and you can see remnants of soap on it.")
	spacer()
	print ("Type 'inventory' to access your items.")
	print ("Your options are: Take, Return.")
	f = str(input("What would you like to do? "))
	spacer()
	x = "Your chose: " + f
	print (x)
	if (f == "Shia LaBouf"):
		print ("\t")
		Shia_LaBouf()
	elif (f == "inventory") or (f == "Inventory"):
		inventory()
		print ("\t")
		strange_fork()
	elif (f == "Take") or (f == "take"):
		fork = bool(True)
		list_inventory.append("Fork")
		spacer()
		print ("You take the fork.")
		print ("\t")
		time.sleep(2.5)
		dining_area()
	elif (f == "Return") or (f == "return"):
		print ("\t")
		dining_area()
	else:
		unavailable()
		strange_fork()

def deserted_kettle ():		#finished
	global kettle
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("You look at the kettle that has been left behind. It seems like it hasn't been used in years. There is rust across the surface of it and there is a horrible smell wafting from it.")
	spacer()
	print ("Type 'inventory' to access your items.")
	print ("Your options are: Take, Return.")
	f = str(input("What would you like to do? "))
	spacer()
	x = "You chose: " + f
	print (x)
	if (f == "Shia LaBouf"):
		print ("\t")
		Shia_LaBouf()
	elif (f == "Inventory") or (f == "inventory"):
		inventory()
		print ("\t")
		deserted_kettle()
	elif (f == "Take") or (f == "take"):
		kettle = bool(True)
		list_inventory.append("Deserted Kettle")
		spacer()
		print ("You take the kettle.")
		print ("\t")
		time.sleep(2.5)
		kitchen()
	elif (f == "Return") or (f == "return"):
		print ("\t")
		kitchen()
	else:
		unavailable()
		deserted_kettle()

def window ():		#finished (flower added)
	global b_key
	global s_key
	global g_key
	global flower_1970
	print ("+++++++++++++++++++++++")
	print ("\t")
	if (flower_1970 == bool(False)):
		print ("It's a window. From what you can see, most of the window has been cracked. Outside, there looks to be a backyard with a faded white fence that is in a state of disarray. There is a calendula flower sitting in a glass vase on the windowsill. ")
		spacer()
		print ("Type 'inventory' to access your inventory.")
		print ("Your options are: Flower, Return.")
		g = str(input("What would you like to do? "))
		spacer()
		o = "You chose: " + g
		print (o)
		if (g == "Shia LaBouf"):
			print ("\t")
			Shia_LaBouf()
		elif (g == "inventory") or (g == "Inventory"):
			print ("\t")
			inventory()
		elif (g == "Flower") or (g == "flower"):
			flower_1970 = bool(True)
			spacer()
			list_inventory.append("Calendula Flower")
			print ("You picked up the flower from the vase.")
			time.sleep(2)
			print ("\t")
			seating_area()
	else:
		print ("It's a window. From what you can see, most of the window has been cracked. Outside, there looks to be a backyard with a faded white fence that is in a state of disarray. There is an empty glass vase on the windowsill.")
		spacer()
		print ("Type 'inventory' to access your inventory.")
		print ("Your options are: Return.")
		d = str(input("What would you like to do? "))
		spacer()
		c = "You chose" + d
		print (c)
		if (d == "Shia LaBouf"):
			print ("\t")
			Shia_LaBouf()
		elif (d == "Inventory") or (d == "inventory"):
			print ("\t")
			inventory()
		elif (d == "Return") or (d == "return"):
			print ("\t")
			seating_area()
		else:
			unavailable()
			seating_area()

def paper ():		#finished
	global b_key
	global s_key
	global g_key
	global flower_1970
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("Some of the pictures are coming off of the paper. You see a glint of light from underneath a picture of the drinking well. Do you investigate?")
	spacer()
	print ("Type 'inventory' to access your inventory.")
	print ("Your options are: Investigate, Return.")
	f =str(input("What would you like to do? "))
	spacer()
	x = "You chose: " + f
	print (x)
	if (f == "Shia LaBouf"):
		print ("\t")
		Shia_LaBouf()
	elif (f == "Inventory") or (f == "inventory"):
		inventory()
		print ("\t")
		paper()
	elif (f == "Investigate") or (f == "investigate") or (f == "i"):
		if (s_key == bool(False)):
			spacer()
			print ("There is a small silver key hanging by the nail that holds the picture.")
			print ("Your options are: Yes, No.")
			o = str(input("Do you take the key? "))
			spacer()
			y = "You chose: " + o
			print (y)
			print ("\t")
			if (o == "Yes") or (o == "yes") or (o == "y"):
				s_key = bool(True)
				list_inventory.append("Silver Key")
				print ("+++++++++++++++++++++++")
				print ("\t")
				print ("You took the silver key from the nail.")
				time.sleep(2.5)
				print ("\t")
				paper()
			elif (o == "no") or (o == "no") or (o == "n"):
				print ("+++++++++++++++++++++++")
				print ("\t")
				paper()
			else:
				unavailable()
				paper()
		else:
			spacer()
			print ("There is nothing there.")
			print ("\t")
			paper()
	elif (f == "Return") or (f == "return"):
		print ("\t")
		bottom_tower()
	else:
		unavailable()
		paper()

def up_hallway ():		#finished
	global b_key
	global s_key
	global g_key
	global flower_1970
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("At the top of the stairs, you find yourself in another hallway facing an opened door.")
	spacer()
	print ("Type 'inventory' to access your inventory.")
	print ("Your options are: Forwards, Downstairs.")
	f = str(input("What would you like to do? "))
	spacer()
	x = "You chose: " + f
	print (x)
	if (f == "Shia LaBouf"):
		print ("\t")
		Shia_LaBouf()
	elif (f == "Inventory") or (f == "inventory"):
		inventory()
		print ("\t")
		up_hallway()
	elif (f == "Forwards") or (f == "forwards"):
		print ("\t")
		room_1()
	elif (f == "Downstairs") or (f == "downstairs"):
		print ("\t")
		hallway()
	else:
		unavailable()
		up_hallway()

def room_1 ():		#finished
	global g_key
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("You find yourself in what you think used to be a young child's room. There is a deteriorating baby cradle near the wall. The door to the hallway is behind you. There is closed door in the corner to your right and directly to your right is a door that's slightly ajar.")
	spacer()
	print ("Type 'inventory' to access your inventory.")
	print ("Your options are: Right, Tower Door, Back.")
	f = str(input("What would you like to do? "))
	spacer()
	x = "You chose: " + f
	print (x)
	if (f == "Shia LaBouf"):
		print ("\t")
		Shia_LaBouf()
	elif (f == "Inventory") or (f == "inventory"):
		inventory()
		print ("\t")
		room_1()
	elif (f == "Right") or (f == "right"):
		print ("\t")
		room_2()
	elif (f == "Tower Door") or (f == "tower door"):
		if (g_key == bool(True)):
			print ("\t")
			higher_tower()
		else:
			spacer()
			print ("The door is locked.")
			print ("\t")
			time.sleep(1.5)
			room_1()
	elif (f == "Back") or (f == "back"):
		print ("\t")
		up_hallway()
	else:
		unavailable()
		room_1()

def room_2 ():		#finished (phone added)
	global g_key
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("This, you could tell, was the main bedroom of the house. There are ruined curtains over the windows on the side of the room and a destroyed mattress in the middle. To the side of the mattress, there is a worn nightstand. On top of the night stand, is an old, green rotary phone.")
	spacer()
	print ("Type 'inventory' to access your inventory.")
	print ("Your options are: Closet, Phone, Back.")
	f = str(input("What would you like to do? "))
	spacer()
	x = "You chose: " + f
	print (x)
	if (f == "ShiaLaBouf"):
		print ("\t")
		Shia_LaBouf()
	elif (f == "Inventory") or (f == "inventory"):
		inventory()
		print ("\t")
		room_2()
	elif (f == "Closet") or (f == "closet"):
		print ("\t")
		tiny_room()
	elif (f == "Phone") or (f == "phone"):
		print ("\t")
		phone()
	elif (f == "Back") or (f == "back"):
		print ("\t")
		room_1()
	else:
		unavailable()
		room_2()

def tiny_room ():		#finished
	global g_key
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("You opened the door to a small room that looks like a closet. There is a ratty looking jacket on a hanger inside of the closet.")
	spacer()
	print ("Type 'inventory' to accress your inventory.")
	print ("Your options are: Hanger, Return.")
	f = str(input("What would you like to do? "))
	spacer()
	x = "You chose: " + f
	print (x)
	if (f == "Shia LaBouf"):
		print ("\t")
		Shia_LaBouf()
	elif (f == "inventory") or (f == "Inventory"):
		inventory()
		print ("\t")
		tiny_room()
	elif (f == "Hanger") or (f == "hanger"):
		print ("\t")
		hanger()
	elif (f == "Return") or (f == "return"):
		print ("\t")
		room_2()
	else:
		unavailable()
		tiny_room()

def higher_tower ():		#finished
	global fire
	fire = bool(True)
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("The second-floor room of the tower. There is a bouquet of calendula flowers on a pedestal in the middle of the room. There is sun shining on them.")
	print ("\t")
	print ("+++++++++++++++++++++++")
	time.sleep(5)
	print ("\t")
	print ("You look around the room. While looking, you notice the bottom tower room through a hole in the floor.")
	print ("\t")
	time.sleep(5)
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("Through the hole in the floor, you notice all the papers in the bottom tower have caught on fire.")
	print ("\t")
	print ("+++++++++++++++++++++++")
	time.sleep(5)
	print ("\t")
	print ("Get out.")
	print ("\t")
	time.sleep(7)
	room_1()

def hanger ():		#finished
	global g_key
	print ("+++++++++++++++++++++++")
	print ("\t")
	if (g_key == bool(False)):
		print ("You look closer at the jacket and see that there is a golden key poking out from one of the pockets.")
	else:
		print ("There is nothing in the jacket.")
		print ("\t")
		tiny_room()
	spacer()
	print ("Type 'inventory' to access your inventory.")
	print ("Your options are: Yes, No.")
	f = str(input("Do you take the key? "))
	spacer()
	x = "You chose: " + f
	print (x)
	if (f == "Shia LaBouf"):
		print ("\t")
		Shia_LaBouf()
	elif(f == "inventory") or (f == "Inventory"):
		inventory()
		print ("\t")
		hanger()
	elif (f == "Yes") or (f == "yes") or (f == "y"):
		list_inventory.append("Gold Key")
		g_key = bool(True)
		spacer()
		print ("You picked up the gold key.")
		print ("\t")
		time.sleep(1.5)
		tiny_room()
	elif (f == "No") or (f == "no") or (f == "n"):
		print ("\t")
		hanger()
	else:
		unavailable()
		hanger()

def phone ():		#finished
	print ("+++++++++++++++++++++++")
	print ("\t")
	print ("You walk over to the phone on the nightstand. It looks like there is small amounts of faded green paint on the receiver of the phone. Do you pick up the receiver?")
	spacer()
	print ("Type 'inventory' to acces your inventory.")
	print ("Your options are: Yes, No.")
	f = str(input("What would you like to do? "))
	spacer()
	x = "You chose: " + f
	print (x)
	if (f == "Shia LaBouf"):
		print ("\t")
		Shia_LaBouf()
	elif (f == "inventory") or (f == "Inventory"):
		inventory()
		print ("\t")
		phone()
	elif (f == "Yes") or (f == "yes"):
		spacer()
		print ("You pick up the reciever of the phone. Somehow, you faintly hear remnants of a past conversation. You hear a quiet voice say, 'Take care of yourself, please.' That's the only thing you hear from the old phone.")
		print ("\t")
		time.sleep(7)
		room_2()
	elif (f == "No") or (f == "no"):
		print ("\t")
		room_2()
	else:
		unavailable()
		phone()

def unavailable ():		#answer unavailable
	spacer()
	print ("That is not an available option.")
	print ("\t")

def inventory ():		#get inventory
	spacer()
	print (list_inventory)
	time.sleep(2)

entrance()
